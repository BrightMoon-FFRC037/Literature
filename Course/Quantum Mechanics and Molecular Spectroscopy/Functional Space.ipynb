# %%
from sympy import *

# %%
x, n = symbols('x,n')
f1 = summation(2/n*(-1)**(n+1)*sin(n*x),(n,1,5))
f1
# Out:
# 2*sin(x) - sin(2*x) + 2*sin(3*x)/3 - sin(4*x)/2 + 2*sin(5*x)/5

# %%
plot(f1,(x,-pi,pi))

# %%
f2 = summation(2/n*(-1)**(n+1)*sin(n*x),(n,1,10))
f2
# Out:
# 2*sin(x) - sin(2*x) + 2*sin(3*x)/3 - sin(4*x)/2 + 2*sin(5*x)/5 - sin(6*x)/3 + 2*sin(7*x)/7 - sin(8*x)/4 + 2*sin(9*x)/9 - sin(10*x)/5

# %%
plot(f2,(x,-pi,pi))

# %%
f3 = summation(2/n*(-1)**(n+1)*sin(n*x),(n,1,15))
f3
# Out:
# 2*sin(x) - sin(2*x) + 2*sin(3*x)/3 - sin(4*x)/2 + 2*sin(5*x)/5 - sin(6*x)/3 + 2*sin(7*x)/7 - sin(8*x)/4 + 2*sin(9*x)/9 - sin(10*x)/5 + 2*sin(11*x)/11 - sin(12*x)/6 + 2*sin(13*x)/13 - sin(14*x)/7 + 2*sin(15*x)/15

# %%
plot(f3,(x,-pi,pi))

# %%
g1 = pi/2+summation(-4/((2*n+1)**2*pi)*cos((2*n+1)*x),(n,0,3))
g1
# Out:
# -4*(cos(x) + cos(3*x)/9 + cos(5*x)/25 + cos(7*x)/49)/pi + pi/2

# %%
plot(g1,(x,-pi,pi))

# %%
g2 = pi/2+summation(-4/((2*n+1)**2*pi)*cos((2*n+1)*x),(n,0,8))
g2
# Out:
# -4*(cos(x) + cos(3*x)/9 + cos(5*x)/25 + cos(7*x)/49 + cos(9*x)/81 + cos(11*x)/121 + cos(13*x)/169 + cos(15*x)/225 + cos(17*x)/289)/pi + pi/2

# %%
plot(g2,(x,-pi,pi))

# %%
g3 = pi/2+summation(-4/((2*n+1)**2*pi)*cos((2*n+1)*x),(n,0,13))
g3
# Out:
# -4*(cos(x) + cos(3*x)/9 + cos(5*x)/25 + cos(7*x)/49 + cos(9*x)/81 + cos(11*x)/121 + cos(13*x)/169 + cos(15*x)/225 + cos(17*x)/289)/pi + pi/2

# %%
plot(g3,(x,-pi,pi))
