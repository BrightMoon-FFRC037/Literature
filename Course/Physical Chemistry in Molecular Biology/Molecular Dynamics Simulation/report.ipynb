# %% [markdown]
# I indeed got an alpha helix in this simulation.
# The conformation seems to be steady since similar structures appears after 716,260 time steps and 914,940 time steps.

# %% [markdown]
# ![long_time.png](attachment:long_time.png)

# %% [markdown]
# ![short_time.png](attachment:short_time.png)
