# %% [markdown]
# # 3(4)

# %%
from sympy import * 
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.exp(-0.15)
x = 147
xp = np.arange(0,148)
K1=(1-A**(x-xp+1))/(A**(x-xp+1)-A**(x+1))
# Out:
# C:\Users\zyan\AppData\Local\Temp\ipykernel_24272\806863580.py:4: RuntimeWarning: divide by zero encountered in divide
#   K1=(1-A**(x-xp+1))/(A**(x-xp+1)-A**(x+1))

# %%
plt.plot(xp,K1)
plt.yscale('log')
plt.ylabel(r'$\lg(K_1)$')
plt.xlabel(r'$x_p$')
# Out:
# Text(0.5, 0, '$x_p$')
