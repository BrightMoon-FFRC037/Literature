# %% [markdown]
# # 2(4)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# %% [markdown]
# ## 无驱动蛋白

# %%
N = 1000
pr = 0.5
np.arange(0,N+1)
k_ax = []
p_ax = []
for i in range(0,N**2+1):
    k_ax.append(i)
    if (N+i) % 2 == 1:
        p_ax.append(0)
    else:
        x = (N+i)//2
        res=binom.pmf(x, i, pr)
        p_ax.append(res)
k_ax=np.array(k_ax)
p_ax=np.array(p_ax)
plt.scatter(k_ax,p_ax)
plt.xscale('log')  # Set x-axis to logarithmic scale

# %% [markdown]
# ## 有驱动蛋白

# %%
N = 1000
pr = 0.9
np.arange(0,N+1)
k_ax = []
p_ax = []
for i in range(0,N**2+1):
    k_ax.append(i)
    if (N+i) % 2 == 1:
        p_ax.append(0)
    else:
        x = (N+i)//2
        res=binom.pmf(x, i, pr)
        p_ax.append(res)
k_ax=np.array(k_ax)
p_ax=np.array(p_ax)
plt.scatter(k_ax,p_ax)
plt.xscale('log')  # Set x-axis to logarithmic scale

# %% [markdown]
# ## 比较的讨论
# 从峰值的大小来看，有驱动蛋白的峰值对应的概率明显更大 $0.036>0.0005$ .
# 并且峰值出现的更早（对应的时间更短）。这二者共同说明了，驱动蛋白的促进作用，加速了输运过程。
