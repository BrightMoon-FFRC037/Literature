# %%
from sympy import *
P,Np,n = symbols('P,Np,n')

# %%
Nns = 4.6*10**6

# %%
P = 1/(1+Nns/Np*exp(n*(-0.65)))
P
# Out:
# 1/(1 + 4600000.0*exp(-0.65*n)/Np)

# %%
n0=15
plot(P.subs(n,n0),(Np,0,1e2),title=f'n={n0}',ylabel='P(bound)',xlabel='Np')

# %%
n0=20
plot(P.subs(n,n0),(Np,0,1e2),title=f'n={n0}',ylabel='P(bound)',xlabel='Np')

# %%
n0=25
plot(P.subs(n,n0),(Np,0,1e2),title=f'n={n0}',ylabel='P(bound)',xlabel='Np')

# %%
1/0.65*ln(4.6*10**6/10)
# Out:
# 20.0599719514850

# %%
1/0.65*ln(4.6*10**6/5)
# Out:
# 21.1263522292696

# %%
1/0.65*ln(3*10**8/100)
# Out:
# 22.9448043794344

# %%
1/(1+3*10**8/100*exp(-6*0.65))
# Out:
# 1.64672118616448e-5

# %%
r = symbols('r')
na2 = 90
u = -ln(4*pi*r**2*(1/(2*pi*na2/3)**0.5)*exp(-0.5*r**2/(na2/3)))
u
# Out:
# -log(0.516397779494322*pi**0.5*r**2*exp(-0.0166666666666667*r**2))

# %%
plot(u,(r,0.1,30))

# %%
float(sqrt(60))
# Out:
# 7.745966692414834

# %%
N=1e4
float((4*pi/3)/(2*pi*N/3)**(3/2))
# Out:
# 1.381976597885342e-06
