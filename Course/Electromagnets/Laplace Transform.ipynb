# %%
from sympy import *

init_printing()
# Define the time-domain variable and Laplace variable
t, s = symbols('t s')

# Define the function in the time domain
f = exp(-t) * Heaviside(t)

# Compute the Laplace Transform
F = laplace_transform(f, t, s)
F
# Out:
# ⎛  1            ⎞
# ⎜─────, -1, True⎟
# ⎝s + 1          ⎠

# %%
# Define the Laplace domain variable and time-domain variable
s, t = symbols('s t')

# Define the function in the Laplace domain
F = 1 / (s + 1)

# Compute the inverse Laplace Transform
f = inverse_laplace_transform(F, s, t)
f
# Out:
#  -t
# ℯ  ⋅θ(t)

# %%
A,M,c,k,p,w = symbols('A,M,c,k,p,\omega')
F = (A*w)/((p**2+w**2)*(M*p**2+c*p+k))
F
# Out:
#             A⋅\omega
# ───────────────────────────────
# ⎛      2    2⎞ ⎛   2          ⎞
# ⎝\omega  + p ⎠⋅⎝M⋅p  + c⋅p + k⎠

# %%
F = (12*p)/(p+3)*(p**2+w**2)
F
# Out:
#      ⎛      2    2⎞
# 12⋅p⋅⎝\omega  + p ⎠
# ───────────────────
#        p + 3

# %%
f = inverse_laplace_transform(F,p,t)
f
# Out:
#          2           ⎛          2     ⎞  -3⋅t
# 12⋅\omega ⋅δ(t) + 12⋅⎝- 3⋅\omega  - 27⎠⋅ℯ    ⋅θ(t) + 84⋅δ(t)

# %%
plot(f.subs({M:1,c:1,k:1,w:1,A:1}),(t,0,50),nb_of_points=50000)
#f.subs({M:1,c:1,k:1,w:1})
